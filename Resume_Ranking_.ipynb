# %%
# !git clone https://github.com/AnnepakaNaveen/Ai-resume-ranking-system.git
# Out:
# Cloning into 'Ai-resume-ranking-system'...
# remote: Enumerating objects: 19, done.
# remote: Counting objects: 100% (19/19), done.
# remote: Compressing objects: 100% (17/17), done.
# remote: Total 19 (delta 5), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (19/19), 571.17 KiB | 31.73 MiB/s, done.
# Resolving deltas: 100% (5/5), done.

# %%
# %cd Ai-resume-ranking-system
# Out:
# /content/Ai-resume-ranking-system

# %%
# !ls
# Out:
#  app.py		      README.md		  resume_ranking.ipynb
# 'Naveen resume.pdf'   requiremenrts.txt  'Suhas Martha_offer_letter.pdf'

# %%
# %%writefile app.py
import streamlit as st
import pandas as pd
from pdfminer.high_level import extract_text
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

st.title("AI Resume Ranking System")
st.write("Developed by Naveen")

job_description = st.text_area("Enter Job Description")

uploaded_files = st.file_uploader(
    "Upload Resume PDFs",
    type=["pdf"],
    accept_multiple_files=True
)

if st.button("Analyze Resumes"):

    resume_texts = []
    resume_names = []

    for file in uploaded_files:
        text = extract_text(file)
        resume_texts.append(text)
        resume_names.append(file.name)

    documents = resume_texts + [job_description]

    vectorizer = TfidfVectorizer()
    vectors = vectorizer.fit_transform(documents)

    similarity = cosine_similarity(vectors[-1], vectors[:-1])

    scores = similarity.flatten()

    df = pd.DataFrame({
        "Resume": resume_names,
        "Score": scores
    })

    df = df.sort_values(by="Score", ascending=False)

    st.subheader("Resume Ranking Results")
    st.dataframe(df)
# Out:
# Overwriting app.py

# %%
# %%writefile requirements.txt
# streamlit
# pandas
# scikit-learn
# pdfminer.six
# Out:
# Writing requirements.txt

# %%
# !git add .

# %%
# !git config --global user.name "AnnepakaNaveen"

# %%
# !git config --global user.email "annepakanaveen19@gmail.com"

# %%
# !git commit -m "Added Streamlit resume ranking system"
# Out:
# [main 4ef2163] Added Streamlit resume ranking system
#  2 files changed, 49 insertions(+), 39 deletions(-)
#  rewrite app.py (86%)
#  create mode 100644 requirements.txt

# %%
# !git push https://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@github.com/AnnepakaNaveen/Ai-resume-ranking-system.git main
# Out:
# Enumerating objects: 6, done.
# Counting objects: 100% (6/6), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (3/3), done.
# Writing objects: 100% (4/4), 910 bytes | 910.00 KiB/s, done.
# Total 4 (delta 1), reused 0 (delta 0), pack-reused 0
# remote: Resolving deltas: 100% (1/1), completed with 1 local object.
# To https://github.com/AnnepakaNaveen/Ai-resume-ranking-system.git
#    93335e2..4ef2163  main -> main
